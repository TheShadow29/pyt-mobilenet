# %%
import matplotlib
matplotlib.use('Agg')
import sys
# sys.path.append("/home/ec2-user/anaconda3/external/fastai/")
sys.path.append('/scratch/arka/miniconda3/external/fastai/')


from tqdm import tqdm
tqdm.monitor_interval = 0

from fastai.imports import *
from fastai.transforms import *
from fastai.conv_learner import *
from fastai.model import *
from fastai.dataset import *
from fastai.sgdr import *
from fastai.plots import *
import json
import pandas as pd
from sklearn.metrics import *

# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
PATH = Path("/scratch/arka/miniconda3/external/fastai/courses/dl2/data/cifar10/")
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
stats = (np.array([ 0.4914 ,  0.48216,  0.44653]), np.array([ 0.24703,  0.24349,  0.26159]))
def get_data(sz,bs):
    tfms = tfms_from_stats(stats, sz, aug_tfms=[RandomFlip()], pad=sz//8)
    return ImageClassifierData.from_paths(PATH, val_name='test', tfms=tfms, bs=bs)

# %%
def total_model_params(summary):
    total_params = 0
    for key,value in summary.items():
        total_params+=int(summary[key]['nb_params'])
    print("Total parameters in the model :"+str(total_params))

# %%
bs=64
sz=32

# %%
class expand_depthwise_block(nn.Module):
    ## Thanks to https://github.com/kuangliu/pytorch-cifar/blob/master/models/mobilenetv2.py
    def __init__(self, in_c, out_c, expansion, stride):
        super().__init__()
        t = expansion
        tk = in_c * t
        self.stride = stride
        self.l1 = nn.Sequential(nn.Conv2d(in_c, tk, 1, bias=False), nn.BatchNorm2d(tk), nn.ReLU6(inplace=True),
                               nn.Conv2d(tk, tk, 3, groups=tk, padding=1, bias=False), nn.BatchNorm2d(tk), nn.ReLU6(inplace=True),
                               nn.Conv2d(tk, out_c, 1, bias=False), nn.BatchNorm2d(out_c))
        self.resd = nn.Sequential()
        if stride == 1 and in_c != out_c:      
            self.resd = nn.Sequential(nn.Conv2d(in_c, out_c, 1, bias=False), nn.BatchNorm2d(out_c))
            
    def forward(self, inp):
        
        out = self.l1(inp)
        if self.stride == 1:
            out = out + self.resd(inp)
        return out

# %%
class mblnetv2(nn.Module):
    def __init__(self, block, inc_scale, inc_start, tuple_list, num_classes):
        super().__init__()
        # assuming tuple list of form:
        # expansion, out_planes, num_blocks, stride 
        self.num_blocks = len(tuple_list)
        self.in_planes = inc_start // inc_scale
        self.conv1 = nn.Conv2d(3, self.in_planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(self.in_planes)
        lyrs = []
        for expf, inc, nb, strl in tuple_list:
            lyrs.append(self._make_layer(block, expf, inc, nb, strl))
            
        self.lyrs = nn.Sequential(*lyrs)
        self.linear = nn.Linear(tuple_list[-1][1], num_classes)
        
    
    def _make_layer(self, block, expf, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, expf, stride))
            self.in_planes = planes
        return nn.Sequential(*layers)
    
    def forward(self, inp):
        out = F.relu(self.bn1(self.conv1(inp)))
        out = self.lyrs(out)
        out = F.adaptive_avg_pool2d(out, 1)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return F.log_softmax(out, dim=-1)

# %%
tpl = [(1,  16, 1, 1),
       (6,  24, 2, 1),  
       (6,  32, 3, 2),
       (6,  64, 4, 2),
       (6,  96, 3, 1),
       (6, 160, 3, 2),
       (6, 320, 1, 1)]
md_mbl = mblnetv2(expand_depthwise_block, 1, 32,
                  tpl,
                  num_classes=10)

# %%
data = get_data(sz, bs)

# %%
learn = ConvLearner.from_model_data(md_mbl, data)

# %%
learn.summary()
# Out:
# OrderedDict([('Conv2d-1',
#               OrderedDict([('input_shape', [-1, 3, 32, 32]),
#                            ('output_shape', [-1, 32, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 864)])),
#              ('BatchNorm2d-2',
#               OrderedDict([('input_shape', [-1, 32, 32, 32]),
#                            ('output_shape', [-1, 32, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 64)])),
#              ('Conv2d-3',
#               OrderedDict([('input_shape', [-1, 32, 32, 32]),
#                            ('output_shape', [-1, 32, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('BatchNorm2d-4',
#               OrderedDict([('input_shape', [-1, 32, 32, 32]),
#                            ('output_shape', [-1, 32, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 64)])),
#              ('ReLU6-5',
#               OrderedDict([('input_shape', [-1, 32, 32, 32]),
#                            ('output_shape', [-1, 32, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-6',
#               OrderedDict([('input_shape', [-1, 32, 32, 32]),
#                            ('output_shape', [-1, 32, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 288)])),
#              ('BatchNorm2d-7',
#               OrderedDict([('input_shape', [-1, 32, 32, 32]),
#                            ('output_shape', [-1, 32, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 64)])),
#              ('ReLU6-8',
#               OrderedDict([('input_shape', [-1, 32, 32, 32]),
#                            ('output_shape', [-1, 32, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-9',
#               OrderedDict([('input_shape', [-1, 32, 32, 32]),
#                            ('output_shape', [-1, 16, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('BatchNorm2d-10',
#               OrderedDict([('input_shape', [-1, 16, 32, 32]),
#                            ('output_shape', [-1, 16, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 32)])),
#              ('Conv2d-11',
#               OrderedDict([('input_shape', [-1, 32, 32, 32]),
#                            ('output_shape', [-1, 16, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('BatchNorm2d-12',
#               OrderedDict([('input_shape', [-1, 16, 32, 32]),
#                            ('output_shape', [-1, 16, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 32)])),
#              ('expand_depthwise_block-13',
#               OrderedDict([('input_shape', [-1, 32, 32, 32]),
#                            ('output_shape', [-1, 16, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-14',
#               OrderedDict([('input_shape', [-1, 16, 32, 32]),
#                            ('output_shape', [-1, 96, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 1536)])),
#              ('BatchNorm2d-15',
#               OrderedDict([('input_shape', [-1, 96, 32, 32]),
#                            ('output_shape', [-1, 96, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 192)])),
#              ('ReLU6-16',
#               OrderedDict([('input_shape', [-1, 96, 32, 32]),
#                            ('output_shape', [-1, 96, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-17',
#               OrderedDict([('input_shape', [-1, 96, 32, 32]),
#                            ('output_shape', [-1, 96, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 864)])),
#              ('BatchNorm2d-18',
#               OrderedDict([('input_shape', [-1, 96, 32, 32]),
#                            ('output_shape', [-1, 96, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 192)])),
#              ('ReLU6-19',
#               OrderedDict([('input_shape', [-1, 96, 32, 32]),
#                            ('output_shape', [-1, 96, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-20',
#               OrderedDict([('input_shape', [-1, 96, 32, 32]),
#                            ('output_shape', [-1, 24, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 2304)])),
#              ('BatchNorm2d-21',
#               OrderedDict([('input_shape', [-1, 24, 32, 32]),
#                            ('output_shape', [-1, 24, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 48)])),
#              ('Conv2d-22',
#               OrderedDict([('input_shape', [-1, 16, 32, 32]),
#                            ('output_shape', [-1, 24, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 384)])),
#              ('BatchNorm2d-23',
#               OrderedDict([('input_shape', [-1, 24, 32, 32]),
#                            ('output_shape', [-1, 24, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 48)])),
#              ('expand_depthwise_block-24',
#               OrderedDict([('input_shape', [-1, 16, 32, 32]),
#                            ('output_shape', [-1, 24, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-25',
#               OrderedDict([('input_shape', [-1, 24, 32, 32]),
#                            ('output_shape', [-1, 144, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 3456)])),
#              ('BatchNorm2d-26',
#               OrderedDict([('input_shape', [-1, 144, 32, 32]),
#                            ('output_shape', [-1, 144, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 288)])),
#              ('ReLU6-27',
#               OrderedDict([('input_shape', [-1, 144, 32, 32]),
#                            ('output_shape', [-1, 144, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-28',
#               OrderedDict([('input_shape', [-1, 144, 32, 32]),
#                            ('output_shape', [-1, 144, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 1296)])),
#              ('BatchNorm2d-29',
#               OrderedDict([('input_shape', [-1, 144, 32, 32]),
#                            ('output_shape', [-1, 144, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 288)])),
#              ('ReLU6-30',
#               OrderedDict([('input_shape', [-1, 144, 32, 32]),
#                            ('output_shape', [-1, 144, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-31',
#               OrderedDict([('input_shape', [-1, 144, 32, 32]),
#                            ('output_shape', [-1, 24, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 3456)])),
#              ('BatchNorm2d-32',
#               OrderedDict([('input_shape', [-1, 24, 32, 32]),
#                            ('output_shape', [-1, 24, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 48)])),
#              ('expand_depthwise_block-33',
#               OrderedDict([('input_shape', [-1, 24, 32, 32]),
#                            ('output_shape', [-1, 24, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-34',
#               OrderedDict([('input_shape', [-1, 24, 32, 32]),
#                            ('output_shape', [-1, 144, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 3456)])),
#              ('BatchNorm2d-35',
#               OrderedDict([('input_shape', [-1, 144, 32, 32]),
#                            ('output_shape', [-1, 144, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 288)])),
#              ('ReLU6-36',
#               OrderedDict([('input_shape', [-1, 144, 32, 32]),
#                            ('output_shape', [-1, 144, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-37',
#               OrderedDict([('input_shape', [-1, 144, 32, 32]),
#                            ('output_shape', [-1, 144, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 1296)])),
#              ('BatchNorm2d-38',
#               OrderedDict([('input_shape', [-1, 144, 32, 32]),
#                            ('output_shape', [-1, 144, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 288)])),
#              ('ReLU6-39',
#               OrderedDict([('input_shape', [-1, 144, 32, 32]),
#                            ('output_shape', [-1, 144, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-40',
#               OrderedDict([('input_shape', [-1, 144, 32, 32]),
#                            ('output_shape', [-1, 32, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 4608)])),
#              ('BatchNorm2d-41',
#               OrderedDict([('input_shape', [-1, 32, 32, 32]),
#                            ('output_shape', [-1, 32, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 64)])),
#              ('expand_depthwise_block-42',
#               OrderedDict([('input_shape', [-1, 24, 32, 32]),
#                            ('output_shape', [-1, 32, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-43',
#               OrderedDict([('input_shape', [-1, 32, 32, 32]),
#                            ('output_shape', [-1, 192, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 6144)])),
#              ('BatchNorm2d-44',
#               OrderedDict([('input_shape', [-1, 192, 32, 32]),
#                            ('output_shape', [-1, 192, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 384)])),
#              ('ReLU6-45',
#               OrderedDict([('input_shape', [-1, 192, 32, 32]),
#                            ('output_shape', [-1, 192, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-46',
#               OrderedDict([('input_shape', [-1, 192, 32, 32]),
#                            ('output_shape', [-1, 192, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 1728)])),
#              ('BatchNorm2d-47',
#               OrderedDict([('input_shape', [-1, 192, 32, 32]),
#                            ('output_shape', [-1, 192, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 384)])),
#              ('ReLU6-48',
#               OrderedDict([('input_shape', [-1, 192, 32, 32]),
#                            ('output_shape', [-1, 192, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-49',
#               OrderedDict([('input_shape', [-1, 192, 32, 32]),
#                            ('output_shape', [-1, 32, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 6144)])),
#              ('BatchNorm2d-50',
#               OrderedDict([('input_shape', [-1, 32, 32, 32]),
#                            ('output_shape', [-1, 32, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 64)])),
#              ('expand_depthwise_block-51',
#               OrderedDict([('input_shape', [-1, 32, 32, 32]),
#                            ('output_shape', [-1, 32, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-52',
#               OrderedDict([('input_shape', [-1, 32, 32, 32]),
#                            ('output_shape', [-1, 192, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 6144)])),
#              ('BatchNorm2d-53',
#               OrderedDict([('input_shape', [-1, 192, 32, 32]),
#                            ('output_shape', [-1, 192, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 384)])),
#              ('ReLU6-54',
#               OrderedDict([('input_shape', [-1, 192, 32, 32]),
#                            ('output_shape', [-1, 192, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-55',
#               OrderedDict([('input_shape', [-1, 192, 32, 32]),
#                            ('output_shape', [-1, 192, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 1728)])),
#              ('BatchNorm2d-56',
#               OrderedDict([('input_shape', [-1, 192, 32, 32]),
#                            ('output_shape', [-1, 192, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 384)])),
#              ('ReLU6-57',
#               OrderedDict([('input_shape', [-1, 192, 32, 32]),
#                            ('output_shape', [-1, 192, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-58',
#               OrderedDict([('input_shape', [-1, 192, 32, 32]),
#                            ('output_shape', [-1, 32, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 6144)])),
#              ('BatchNorm2d-59',
#               OrderedDict([('input_shape', [-1, 32, 32, 32]),
#                            ('output_shape', [-1, 32, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 64)])),
#              ('expand_depthwise_block-60',
#               OrderedDict([('input_shape', [-1, 32, 32, 32]),
#                            ('output_shape', [-1, 32, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-61',
#               OrderedDict([('input_shape', [-1, 32, 32, 32]),
#                            ('output_shape', [-1, 192, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 6144)])),
#              ('BatchNorm2d-62',
#               OrderedDict([('input_shape', [-1, 192, 32, 32]),
#                            ('output_shape', [-1, 192, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 384)])),
#              ('ReLU6-63',
#               OrderedDict([('input_shape', [-1, 192, 32, 32]),
#                            ('output_shape', [-1, 192, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-64',
#               OrderedDict([('input_shape', [-1, 192, 32, 32]),
#                            ('output_shape', [-1, 192, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 1728)])),
#              ('BatchNorm2d-65',
#               OrderedDict([('input_shape', [-1, 192, 32, 32]),
#                            ('output_shape', [-1, 192, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 384)])),
#              ('ReLU6-66',
#               OrderedDict([('input_shape', [-1, 192, 32, 32]),
#                            ('output_shape', [-1, 192, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-67',
#               OrderedDict([('input_shape', [-1, 192, 32, 32]),
#                            ('output_shape', [-1, 64, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 12288)])),
#              ('BatchNorm2d-68',
#               OrderedDict([('input_shape', [-1, 64, 32, 32]),
#                            ('output_shape', [-1, 64, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 128)])),
#              ('expand_depthwise_block-69',
#               OrderedDict([('input_shape', [-1, 32, 32, 32]),
#                            ('output_shape', [-1, 64, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-70',
#               OrderedDict([('input_shape', [-1, 64, 32, 32]),
#                            ('output_shape', [-1, 384, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 24576)])),
#              ('BatchNorm2d-71',
#               OrderedDict([('input_shape', [-1, 384, 32, 32]),
#                            ('output_shape', [-1, 384, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 768)])),
#              ('ReLU6-72',
#               OrderedDict([('input_shape', [-1, 384, 32, 32]),
#                            ('output_shape', [-1, 384, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-73',
#               OrderedDict([('input_shape', [-1, 384, 32, 32]),
#                            ('output_shape', [-1, 384, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 3456)])),
#              ('BatchNorm2d-74',
#               OrderedDict([('input_shape', [-1, 384, 32, 32]),
#                            ('output_shape', [-1, 384, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 768)])),
#              ('ReLU6-75',
#               OrderedDict([('input_shape', [-1, 384, 32, 32]),
#                            ('output_shape', [-1, 384, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-76',
#               OrderedDict([('input_shape', [-1, 384, 32, 32]),
#                            ('output_shape', [-1, 64, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 24576)])),
#              ('BatchNorm2d-77',
#               OrderedDict([('input_shape', [-1, 64, 32, 32]),
#                            ('output_shape', [-1, 64, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 128)])),
#              ('expand_depthwise_block-78',
#               OrderedDict([('input_shape', [-1, 64, 32, 32]),
#                            ('output_shape', [-1, 64, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-79',
#               OrderedDict([('input_shape', [-1, 64, 32, 32]),
#                            ('output_shape', [-1, 384, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 24576)])),
#              ('BatchNorm2d-80',
#               OrderedDict([('input_shape', [-1, 384, 32, 32]),
#                            ('output_shape', [-1, 384, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 768)])),
#              ('ReLU6-81',
#               OrderedDict([('input_shape', [-1, 384, 32, 32]),
#                            ('output_shape', [-1, 384, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-82',
#               OrderedDict([('input_shape', [-1, 384, 32, 32]),
#                            ('output_shape', [-1, 384, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 3456)])),
#              ('BatchNorm2d-83',
#               OrderedDict([('input_shape', [-1, 384, 32, 32]),
#                            ('output_shape', [-1, 384, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 768)])),
#              ('ReLU6-84',
#               OrderedDict([('input_shape', [-1, 384, 32, 32]),
#                            ('output_shape', [-1, 384, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-85',
#               OrderedDict([('input_shape', [-1, 384, 32, 32]),
#                            ('output_shape', [-1, 64, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 24576)])),
#              ('BatchNorm2d-86',
#               OrderedDict([('input_shape', [-1, 64, 32, 32]),
#                            ('output_shape', [-1, 64, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 128)])),
#              ('expand_depthwise_block-87',
#               OrderedDict([('input_shape', [-1, 64, 32, 32]),
#                            ('output_shape', [-1, 64, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-88',
#               OrderedDict([('input_shape', [-1, 64, 32, 32]),
#                            ('output_shape', [-1, 384, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 24576)])),
#              ('BatchNorm2d-89',
#               OrderedDict([('input_shape', [-1, 384, 32, 32]),
#                            ('output_shape', [-1, 384, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 768)])),
#              ('ReLU6-90',
#               OrderedDict([('input_shape', [-1, 384, 32, 32]),
#                            ('output_shape', [-1, 384, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-91',
#               OrderedDict([('input_shape', [-1, 384, 32, 32]),
#                            ('output_shape', [-1, 384, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 3456)])),
#              ('BatchNorm2d-92',
#               OrderedDict([('input_shape', [-1, 384, 32, 32]),
#                            ('output_shape', [-1, 384, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 768)])),
#              ('ReLU6-93',
#               OrderedDict([('input_shape', [-1, 384, 32, 32]),
#                            ('output_shape', [-1, 384, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-94',
#               OrderedDict([('input_shape', [-1, 384, 32, 32]),
#                            ('output_shape', [-1, 64, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 24576)])),
#              ('BatchNorm2d-95',
#               OrderedDict([('input_shape', [-1, 64, 32, 32]),
#                            ('output_shape', [-1, 64, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 128)])),
#              ('expand_depthwise_block-96',
#               OrderedDict([('input_shape', [-1, 64, 32, 32]),
#                            ('output_shape', [-1, 64, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-97',
#               OrderedDict([('input_shape', [-1, 64, 32, 32]),
#                            ('output_shape', [-1, 384, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 24576)])),
#              ('BatchNorm2d-98',
#               OrderedDict([('input_shape', [-1, 384, 32, 32]),
#                            ('output_shape', [-1, 384, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 768)])),
#              ('ReLU6-99',
#               OrderedDict([('input_shape', [-1, 384, 32, 32]),
#                            ('output_shape', [-1, 384, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-100',
#               OrderedDict([('input_shape', [-1, 384, 32, 32]),
#                            ('output_shape', [-1, 384, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 3456)])),
#              ('BatchNorm2d-101',
#               OrderedDict([('input_shape', [-1, 384, 32, 32]),
#                            ('output_shape', [-1, 384, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 768)])),
#              ('ReLU6-102',
#               OrderedDict([('input_shape', [-1, 384, 32, 32]),
#                            ('output_shape', [-1, 384, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-103',
#               OrderedDict([('input_shape', [-1, 384, 32, 32]),
#                            ('output_shape', [-1, 96, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 36864)])),
#              ('BatchNorm2d-104',
#               OrderedDict([('input_shape', [-1, 96, 32, 32]),
#                            ('output_shape', [-1, 96, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 192)])),
#              ('Conv2d-105',
#               OrderedDict([('input_shape', [-1, 64, 32, 32]),
#                            ('output_shape', [-1, 96, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 6144)])),
#              ('BatchNorm2d-106',
#               OrderedDict([('input_shape', [-1, 96, 32, 32]),
#                            ('output_shape', [-1, 96, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 192)])),
#              ('expand_depthwise_block-107',
#               OrderedDict([('input_shape', [-1, 64, 32, 32]),
#                            ('output_shape', [-1, 96, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-108',
#               OrderedDict([('input_shape', [-1, 96, 32, 32]),
#                            ('output_shape', [-1, 576, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 55296)])),
#              ('BatchNorm2d-109',
#               OrderedDict([('input_shape', [-1, 576, 32, 32]),
#                            ('output_shape', [-1, 576, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 1152)])),
#              ('ReLU6-110',
#               OrderedDict([('input_shape', [-1, 576, 32, 32]),
#                            ('output_shape', [-1, 576, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-111',
#               OrderedDict([('input_shape', [-1, 576, 32, 32]),
#                            ('output_shape', [-1, 576, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 5184)])),
#              ('BatchNorm2d-112',
#               OrderedDict([('input_shape', [-1, 576, 32, 32]),
#                            ('output_shape', [-1, 576, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 1152)])),
#              ('ReLU6-113',
#               OrderedDict([('input_shape', [-1, 576, 32, 32]),
#                            ('output_shape', [-1, 576, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-114',
#               OrderedDict([('input_shape', [-1, 576, 32, 32]),
#                            ('output_shape', [-1, 96, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 55296)])),
#              ('BatchNorm2d-115',
#               OrderedDict([('input_shape', [-1, 96, 32, 32]),
#                            ('output_shape', [-1, 96, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 192)])),
#              ('expand_depthwise_block-116',
#               OrderedDict([('input_shape', [-1, 96, 32, 32]),
#                            ('output_shape', [-1, 96, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-117',
#               OrderedDict([('input_shape', [-1, 96, 32, 32]),
#                            ('output_shape', [-1, 576, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 55296)])),
#              ('BatchNorm2d-118',
#               OrderedDict([('input_shape', [-1, 576, 32, 32]),
#                            ('output_shape', [-1, 576, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 1152)])),
#              ('ReLU6-119',
#               OrderedDict([('input_shape', [-1, 576, 32, 32]),
#                            ('output_shape', [-1, 576, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-120',
#               OrderedDict([('input_shape', [-1, 576, 32, 32]),
#                            ('output_shape', [-1, 576, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 5184)])),
#              ('BatchNorm2d-121',
#               OrderedDict([('input_shape', [-1, 576, 32, 32]),
#                            ('output_shape', [-1, 576, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 1152)])),
#              ('ReLU6-122',
#               OrderedDict([('input_shape', [-1, 576, 32, 32]),
#                            ('output_shape', [-1, 576, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-123',
#               OrderedDict([('input_shape', [-1, 576, 32, 32]),
#                            ('output_shape', [-1, 96, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 55296)])),
#              ('BatchNorm2d-124',
#               OrderedDict([('input_shape', [-1, 96, 32, 32]),
#                            ('output_shape', [-1, 96, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 192)])),
#              ('expand_depthwise_block-125',
#               OrderedDict([('input_shape', [-1, 96, 32, 32]),
#                            ('output_shape', [-1, 96, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-126',
#               OrderedDict([('input_shape', [-1, 96, 32, 32]),
#                            ('output_shape', [-1, 576, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 55296)])),
#              ('BatchNorm2d-127',
#               OrderedDict([('input_shape', [-1, 576, 32, 32]),
#                            ('output_shape', [-1, 576, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 1152)])),
#              ('ReLU6-128',
#               OrderedDict([('input_shape', [-1, 576, 32, 32]),
#                            ('output_shape', [-1, 576, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-129',
#               OrderedDict([('input_shape', [-1, 576, 32, 32]),
#                            ('output_shape', [-1, 576, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 5184)])),
#              ('BatchNorm2d-130',
#               OrderedDict([('input_shape', [-1, 576, 32, 32]),
#                            ('output_shape', [-1, 576, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 1152)])),
#              ('ReLU6-131',
#               OrderedDict([('input_shape', [-1, 576, 32, 32]),
#                            ('output_shape', [-1, 576, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-132',
#               OrderedDict([('input_shape', [-1, 576, 32, 32]),
#                            ('output_shape', [-1, 160, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 92160)])),
#              ('BatchNorm2d-133',
#               OrderedDict([('input_shape', [-1, 160, 32, 32]),
#                            ('output_shape', [-1, 160, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 320)])),
#              ('expand_depthwise_block-134',
#               OrderedDict([('input_shape', [-1, 96, 32, 32]),
#                            ('output_shape', [-1, 160, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-135',
#               OrderedDict([('input_shape', [-1, 160, 32, 32]),
#                            ('output_shape', [-1, 960, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 153600)])),
#              ('BatchNorm2d-136',
#               OrderedDict([('input_shape', [-1, 960, 32, 32]),
#                            ('output_shape', [-1, 960, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 1920)])),
#              ('ReLU6-137',
#               OrderedDict([('input_shape', [-1, 960, 32, 32]),
#                            ('output_shape', [-1, 960, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-138',
#               OrderedDict([('input_shape', [-1, 960, 32, 32]),
#                            ('output_shape', [-1, 960, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 8640)])),
#              ('BatchNorm2d-139',
#               OrderedDict([('input_shape', [-1, 960, 32, 32]),
#                            ('output_shape', [-1, 960, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 1920)])),
#              ('ReLU6-140',
#               OrderedDict([('input_shape', [-1, 960, 32, 32]),
#                            ('output_shape', [-1, 960, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-141',
#               OrderedDict([('input_shape', [-1, 960, 32, 32]),
#                            ('output_shape', [-1, 160, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 153600)])),
#              ('BatchNorm2d-142',
#               OrderedDict([('input_shape', [-1, 160, 32, 32]),
#                            ('output_shape', [-1, 160, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 320)])),
#              ('expand_depthwise_block-143',
#               OrderedDict([('input_shape', [-1, 160, 32, 32]),
#                            ('output_shape', [-1, 160, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-144',
#               OrderedDict([('input_shape', [-1, 160, 32, 32]),
#                            ('output_shape', [-1, 960, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 153600)])),
#              ('BatchNorm2d-145',
#               OrderedDict([('input_shape', [-1, 960, 32, 32]),
#                            ('output_shape', [-1, 960, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 1920)])),
#              ('ReLU6-146',
#               OrderedDict([('input_shape', [-1, 960, 32, 32]),
#                            ('output_shape', [-1, 960, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-147',
#               OrderedDict([('input_shape', [-1, 960, 32, 32]),
#                            ('output_shape', [-1, 960, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 8640)])),
#              ('BatchNorm2d-148',
#               OrderedDict([('input_shape', [-1, 960, 32, 32]),
#                            ('output_shape', [-1, 960, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 1920)])),
#              ('ReLU6-149',
#               OrderedDict([('input_shape', [-1, 960, 32, 32]),
#                            ('output_shape', [-1, 960, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-150',
#               OrderedDict([('input_shape', [-1, 960, 32, 32]),
#                            ('output_shape', [-1, 160, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 153600)])),
#              ('BatchNorm2d-151',
#               OrderedDict([('input_shape', [-1, 160, 32, 32]),
#                            ('output_shape', [-1, 160, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 320)])),
#              ('expand_depthwise_block-152',
#               OrderedDict([('input_shape', [-1, 160, 32, 32]),
#                            ('output_shape', [-1, 160, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-153',
#               OrderedDict([('input_shape', [-1, 160, 32, 32]),
#                            ('output_shape', [-1, 960, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 153600)])),
#              ('BatchNorm2d-154',
#               OrderedDict([('input_shape', [-1, 960, 32, 32]),
#                            ('output_shape', [-1, 960, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 1920)])),
#              ('ReLU6-155',
#               OrderedDict([('input_shape', [-1, 960, 32, 32]),
#                            ('output_shape', [-1, 960, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-156',
#               OrderedDict([('input_shape', [-1, 960, 32, 32]),
#                            ('output_shape', [-1, 960, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 8640)])),
#              ('BatchNorm2d-157',
#               OrderedDict([('input_shape', [-1, 960, 32, 32]),
#                            ('output_shape', [-1, 960, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 1920)])),
#              ('ReLU6-158',
#               OrderedDict([('input_shape', [-1, 960, 32, 32]),
#                            ('output_shape', [-1, 960, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-159',
#               OrderedDict([('input_shape', [-1, 960, 32, 32]),
#                            ('output_shape', [-1, 320, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 307200)])),
#              ('BatchNorm2d-160',
#               OrderedDict([('input_shape', [-1, 320, 32, 32]),
#                            ('output_shape', [-1, 320, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 640)])),
#              ('Conv2d-161',
#               OrderedDict([('input_shape', [-1, 160, 32, 32]),
#                            ('output_shape', [-1, 320, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 51200)])),
#              ('BatchNorm2d-162',
#               OrderedDict([('input_shape', [-1, 320, 32, 32]),
#                            ('output_shape', [-1, 320, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 640)])),
#              ('expand_depthwise_block-163',
#               OrderedDict([('input_shape', [-1, 160, 32, 32]),
#                            ('output_shape', [-1, 320, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Linear-164',
#               OrderedDict([('input_shape', [-1, 320]),
#                            ('output_shape', [-1, 10]),
#                            ('trainable', True),
#                            ('nb_params', 3210)]))])

# %%
total_model_params(learn.summary())
# Out:
# Total parameters in the model :1875162

# %%
learn.fit(1e-2, 5, cycle_len=1, cycle_mult=2, best_save_name='best_mblnetv2_1', metrics=[accuracy])
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=31), HTML(value='')))
# epoch      trn_loss   val_loss   accuracy
#     0      1.209806   1.137405   0.5947
#     1      0.946034   0.94159    0.664
#     2      0.770191   0.733759   0.7424
#     3      0.815635   0.834312   0.7117
#     4      0.669764   0.706938   0.7568
#     5      0.52917    0.524191   0.816
#     6      0.475442   0.482743   0.8322
#     7      0.614684   0.661572   0.7648
#     8      0.541954   0.610943   0.7926
#     9      0.492407   0.529143   0.8206
#     10     0.44874    0.455056   0.8491
#     11     0.396531   0.402671   0.8636
#     12     0.326405   0.371117   0.8735
#     13     0.287955   0.358939   0.8791
#     14     0.286139   0.355971   0.8793
#     15     0.474716   0.622466   0.7945
#     16     0.435346   0.509328   0.8303
#     17     0.40321    0.445755   0.8481
#     18     0.357457   0.461874   0.8434
#     19     0.345304   0.389876   0.8708
#     21     0.275781   0.371818   0.8848
#     22     0.24549    0.391909   0.8754
#     23     0.240732   0.323678   0.8929
#     24     0.199097   0.352068   0.884
#     25     0.162869   0.31686    0.8947
#     26     0.135588   0.309907   0.8989
#     27     0.123746   0.311558   0.8997
#     28     0.111402   0.299865   0.9014
#     29     0.10498    0.300633   0.9034
#     30     0.100853   0.300571   0.904
# [array([0.30057]), 0.904]
